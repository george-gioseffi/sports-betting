# %% [markdown]
# # Prototype Metrics\n\nSandbox notebook for validating KPI ideas before codifying in `src/analytics/metrics_calculator.py`.

# %%
from src.analytics.metrics_calculator import calculate_core_metrics\nimport pandas as pd\n\nbets = pd.read_csv('../data/staging/bets_staging.csv')\ncalculate_core_metrics(bets)
