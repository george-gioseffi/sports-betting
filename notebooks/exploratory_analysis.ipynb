# %% [markdown]
# # Exploratory Analysis\n\nThis notebook is optional support material. The production logic lives in `src/`.

# %%
import pandas as pd\nbets = pd.read_csv('../data/marts/fact_bets.csv')\nbets.head()
